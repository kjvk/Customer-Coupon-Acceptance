# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly as px
import plotly.express as pxx

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
# 3        never       NaN                  4~8              1~3
# 4        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
#  15  Bar                   12577 non-null  object
#  16  CoffeeHouse           12467 non-null  object
#  17  CarryAway             12533 non-null  object
#  18  RestaurantLessThan20  12554 non-null  object
#  19  Restaurant20To50      12495 non-null  object
#  20  toCoupon_GEQ5min      12684 non-null  int64
#  21  toCoupon_GEQ15min     12684 non-null  int64
#  22  toCoupon_GEQ25min     12684 non-null  int64
#  23  direction_same        12684 non-null  int64
#  24  direction_opp         12684 non-null  int64
#  25  Y                     12684 non-null  int64
# dtypes: int64(8), object(18)
# memory usage: 2.5+ MB

# %%
data.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# min             0.000000        0.000000       0.000000      0.000000
# 25%             0.000000        0.000000       1.000000      0.000000
# 50%             0.000000        0.000000       1.000000      1.000000
# 75%             0.000000        0.000000       1.000000      1.000000
# max             1.000000        1.000000       1.000000      1.000000

# %%
sns.pairplot(data, hue="coupon")
# Out:
# /Users/krishnakuncham/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###Description of the below columns is not avaialble.
#
#
# toCoupon_GEQ5min,
# toCoupon_GEQ15min,
# toCoupon_GEQ25min

# %%
data['toCoupon_GEQ5min'].unique()
# Out:
# array([1])

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
data['car'].unique()
# Out:
# array([nan, 'Scooter and motorcycle', 'crossover', 'Mazda5',
#        'do not drive', 'Car that is too old to install Onstar :D'],
#       dtype=object)

# %% [markdown]
# ### Below columns can be dropped from the analysis as there is not much information or data description available.
#
#
#     car
#     toCoupon_GEQ5min
#     toCoupon_GEQ15min
#     toCoupon_GEQ25mi columns

# %%
data = data.drop(['car','toCoupon_GEQ5min','toCoupon_GEQ15min','toCoupon_GEQ25min'], axis=1)

# %% [markdown]
# ## Duplicates in the Data

# %%
data[data.duplicated()]
# Out:
#            destination  passanger weather  temperature time           coupon  \
# 21                Work      Alone   Sunny           55  7AM     Coffee House
# 28     No Urgent Place  Friend(s)   Sunny           80  2PM     Coffee House
# 43                Work      Alone   Sunny           55  7AM     Coffee House
# 65                Work      Alone   Sunny           55  7AM     Coffee House
# 87                Work      Alone   Sunny           55  7AM     Coffee House
# ...                ...        ...     ...          ...  ...              ...
# 11147  No Urgent Place     Kid(s)   Snowy           30  6PM              Bar
# 11367  No Urgent Place     Kid(s)   Snowy           30  6PM              Bar
# 11932  No Urgent Place  Friend(s)   Sunny           80  6PM  Restaurant(<20)
# 12173  No Urgent Place  Friend(s)   Sunny           80  6PM  Restaurant(<20)
# 12635  No Urgent Place     Kid(s)   Snowy           30  6PM              Bar
#
#       expiration  gender age      maritalStatus  ...  \
# 21            2h  Female  21  Unmarried partner  ...
# 28            1d    Male  21             Single  ...
# 43            2h    Male  21             Single  ...
# 65            2h    Male  46             Single  ...
# 87            2h    Male  46    Married partner  ...
# ...          ...     ...  ..                ...  ...
# 11147         1d  Female  41    Married partner  ...
# 11367         1d  Female  21    Married partner  ...
# 11932         2h  Female  31    Married partner  ...
# 12173         2h    Male  26             Single  ...
# 12635         1d  Female  26    Married partner  ...
#
#                                      occupation           income    Bar  \
# 21                                   Unemployed  $37500 - $49999  never
# 28                   Architecture & Engineering  $62500 - $74999  never
# 43                   Architecture & Engineering  $62500 - $74999  never
# 65                                      Student  $12500 - $24999  never
# 87                   Education&Training&Library  $75000 - $87499  less1
# ...                                         ...              ...    ...
# 11147                   Computer & Mathematical  $75000 - $87499  less1
# 11367                                Unemployed  $50000 - $62499  never
# 11932                   Computer & Mathematical  $100000 or More  less1
# 12173                                Unemployed  $37500 - $49999    gt8
# 12635  Arts Design Entertainment Sports & Media  $50000 - $62499  never
#
#       CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 21          never       NaN                  4~8              1~3
# 28          less1       4~8                  4~8            less1
# 43          less1       4~8                  4~8            less1
# 65            4~8       1~3                  1~3            never
# 87            1~3       1~3                  1~3            less1
# ...           ...       ...                  ...              ...
# 11147         4~8       gt8                  1~3            less1
# 11367         1~3       1~3                  1~3              1~3
# 11932       less1       gt8                  4~8            less1
# 12173         gt8       gt8                  gt8              gt8
# 12635       never     less1                less1            less1
#
#       direction_same direction_opp  Y
# 21                 0             1  1
# 28                 0             1  0
# 43                 0             1  0
# 65                 0             1  0
# 87                 0             1  0
# ...              ...           ... ..
# 11147              0             1  0
# 11367              0             1  0
# 11932              0             1  1
# 12173              0             1  0
# 12635              0             1  0
#
# [470 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)
data[(data['destination']=='Home') & (data['passanger']=='Alone') & (data['weather']=='Sunny') & \
     (data['temperature']==80) & (data['coupon']=='Bar') & (data['expiration']=='2h') & \
    (data['gender']=='Male') & (data['age']=='46') ]
# Out:
#      destination passanger weather  temperature time coupon expiration gender  \
# 7189        Home     Alone   Sunny           80  6PM    Bar         2h   Male
# 7409        Home     Alone   Sunny           80  6PM    Bar         2h   Male
# 8511        Home     Alone   Sunny           80  6PM    Bar         2h   Male
#
#      age    maritalStatus  has_children  \
# 7189  46           Single             0
# 7409  46  Married partner             1
# 8511  46  Married partner             1
#
#                                    education               occupation  \
# 7189  Graduate degree (Masters or Doctorate)  Computer & Mathematical
# 7409  Graduate degree (Masters or Doctorate)               Management
# 8511  Graduate degree (Masters or Doctorate)               Management
#
#                income    Bar CoffeeHouse CarryAway RestaurantLessThan20  \
# 7189  $37500 - $49999  never         gt8       1~3                  4~8
# 7409  $87500 - $99999  less1         1~3       1~3                less1
# 8511  $87500 - $99999  less1         1~3       1~3                less1
#
#      Restaurant20To50  direction_same  direction_opp  Y
# 7189            less1               1              0  0
# 7409              1~3               1              0  1
# 8511              1~3               1              0  1

# %%
print('Before Duplicates',data.shape)
#duplicate_data = data[data.duplicated()]
#new_data = data.drop(duplicate_data.index)
data = data.drop_duplicates()
print('After Duplicates',data.shape)
# Out:
# Before Duplicates (12684, 22)
# After Duplicates (12214, 22)

# %%
#data = data.drop(['car'], axis=1) ## Removed the car column.
data.isnull().sum()
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                     105
# CoffeeHouse             212
# CarryAway               146
# RestaurantLessThan20    124
# Restaurant20To50        187
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %% [markdown]
# ### Handling Missig Values
#
# Handle the missing values by imputation, this data consists of both Numerical and categorical values. We are filling the missing data by most frequent values utilizing the Imputaion by Mode. Before imputing let's find out the categorical columns.

# %%
data.columns[data.dtypes == 'object']
# Out:
# Index(['destination', 'passanger', 'weather', 'time', 'coupon', 'expiration',
#        'gender', 'age', 'maritalStatus', 'education', 'occupation', 'income',
#        'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20',
#        'Restaurant20To50'],
#       dtype='object')

# %% [markdown]
# ###
# #### Most frequent values of the missing value columns

# %%
print(data['Bar'].value_counts())
print(data['CoffeeHouse'].value_counts())
print(data['CarryAway'].value_counts())
print(data['RestaurantLessThan20'].value_counts())
print(data['Restaurant20To50'].value_counts())
# Out:
# Bar
# never    5017
# less1    3336
# 1~3      2390
# 4~8      1032
# gt8       334
# Name: count, dtype: int64
# CoffeeHouse
# less1    3258
# 1~3      3095
# never    2847
# 4~8      1735
# gt8      1067
# Name: count, dtype: int64
# CarryAway
# 1~3      4495
# 4~8      4108
# less1    1802
# gt8      1514
# never     149
# Name: count, dtype: int64
# RestaurantLessThan20
# 1~3      5195
# 4~8      3446
# less1    2008
# gt8      1225
# never     216
# Name: count, dtype: int64
# Restaurant20To50
# less1    5861
# 1~3      3153
# never    2046
# 4~8       716
# gt8       251
# Name: count, dtype: int64

# %%
data['Bar'] = data['Bar'].fillna(data['Bar'].mode()[0])
data['CoffeeHouse'] = data['CoffeeHouse'].fillna(data['CoffeeHouse'].mode()[0])
data['CarryAway'] = data['CarryAway'].fillna(data['CarryAway'].mode()[0])
data['RestaurantLessThan20'] = data['RestaurantLessThan20'].fillna(data['RestaurantLessThan20'].mode()[0])
data['Restaurant20To50'] = data['Restaurant20To50'].fillna(data['Restaurant20To50'].mode()[0])

print(data.isnull().sum())
print(data.shape)
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64
# (12214, 22)

# %% [markdown]
# There are no more missing values in the dataset.
# Let's convert all the categorical values to the Numerical values. With numerical values it is easy to identify the corelation between the features.

# %% [markdown]
# ### Acceptance by Passanger

# %%
data.passanger.unique()
# Out:
# array(['Alone', 'Friend(s)', 'Kid(s)', 'Partner'], dtype=object)

# %%
data_pa1 = data[data['passanger']=='Alone']
data_pa1
ax = sns.countplot(data_pa1, x="coupon", hue="Y")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set(title="Coupon accepted vs not-accepted when drivers are Alone")
plt.tight_layout()
plt.show()

# %%
data_pa1 = data[data['passanger']=='Friend(s)']
data_pa1
ax = sns.countplot(data_pa1, x="coupon", hue="Y")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set(title="Coupon accepted vs not-accepted when drivers are with Friend(s) as passengers")
plt.tight_layout()
plt.show()

# %%
data_pa1 = data[data['passanger']=='Kid(s)']
data_pa1
ax = sns.countplot(data_pa1, x="coupon", hue="Y")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set(title="Coupon accepted vs not-accepted when drivers are with Kid(s) as passengers")
plt.tight_layout()
plt.show()

# %%
data_pa1 = data[data['passanger']=='Partner']
data_pa1
ax = sns.countplot(data_pa1, x="coupon", hue="Y")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set(title="Coupon accepted vs not-accepted when drivers are with Partner as passengers")
plt.tight_layout()
plt.show()

# %%
data_accepted = data[data['Y']==1]
pxx.histogram(data_accepted, x='passanger', color='coupon', text_auto=True, title='Acceptance of coupons by Passengers')
# Out:
# <div>                            <div id="55c8889b-7985-4db6-a19c-d0127f6748aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55c8889b-7985-4db6-a19c-d0127f6748aa")) {                    Plotly.newPlot(                        "55c8889b-7985-4db6-a19c-d0127f6748aa",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"coupon=Restaurant(<20)<br>passanger=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Restaurant(<20)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Restaurant(<20)","offsetgroup":"Restaurant(<20)","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Friend(s)","Friend(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Alone","Alone","Friend(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Friend(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Friend(s)","Partner","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Partner","Alone","Partner","Alone","Kid(s)","Kid(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Partner","Alone","Alone","Friend(s)","Partner","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Kid(s)","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Partner","Alone","Alone","Friend(s)","Partner","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Kid(s)","Kid(s)","Kid(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Friend(s)","Alone","Alone","Friend(s)","Partner","Alone","Alone","Friend(s)","Kid(s)","Ki ...

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
data_coupon = [data[data['Y']==1].shape[0],data[data['Y']!=1].shape[0]]
print(data_coupon)
keys = ['Accepted', 'Not Accepted']
palette_color = sns.color_palette('bright')
plt.pie(data_coupon, labels=keys, colors=palette_color, autopct='%.0f%%')
plt.title("Coupon Acceptance Ratio")
plt.show()
# Out:
# [6979, 5235]

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
df_coupon_bar = data['coupon']
df_coupon_bar.value_counts().plot(kind='bar', title='Coupon varieties and Counts', xlabel='Coupons', ylabel='Count')
# Out:
# <Axes: title={'center': 'Coupon varieties and Counts'}, xlabel='Coupons', ylabel='Count'>

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.displot(data=data, x='temperature').set(title = 'Histogram of Temperature')
# Out:
# /Users/krishnakuncham/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
data_coupon_bar = data[data['coupon']=='Bar']
data_coupon_bar
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  has_children  \
# 9             1d  Female  21  Unmarried partner             1
# 13            1d  Female  21  Unmarried partner             1
# 17            1d  Female  21  Unmarried partner             1
# 24            1d    Male  21             Single             0
# 35            1d    Male  21             Single             0
# ...          ...     ...  ..                ...           ...
# 12663         1d    Male  26             Single             0
# 12664         2h    Male  26             Single             0
# 12667         1d    Male  26             Single             0
# 12670         2h    Male  26             Single             0
# 12682         1d    Male  26             Single             0
#
#                       education                  occupation           income  \
# 9      Some college - no degree                  Unemployed  $37500 - $49999
# 13     Some college - no degree                  Unemployed  $37500 - $49999
# 17     Some college - no degree                  Unemployed  $37500 - $49999
# 24             Bachelors degree  Architecture & Engineering  $62500 - $74999
# 35             Bachelors degree  Architecture & Engineering  $62500 - $74999
# ...                         ...                         ...              ...
# 12663          Bachelors degree             Sales & Related  $75000 - $87499
# 12664          Bachelors degree             Sales & Related  $75000 - $87499
# 12667          Bachelors degree             Sales & Related  $75000 - $87499
# 12670          Bachelors degree             Sales & Related  $75000 - $87499
# 12682          Bachelors degree             Sales & Related  $75000 - $87499
#
#          Bar CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 9      never       never       1~3                  4~8              1~3
# 13     never       never       1~3                  4~8              1~3
# 17     never       never       1~3                  4~8              1~3
# 24     never       less1       4~8                  4~8            less1
# 35     never       less1       4~8                  4~8            less1
# ...      ...         ...       ...                  ...              ...
# 12663  never       never       1~3                  4~8              1~3
# 12664  never       never       1~3                  4~8              1~3
# 12667  never       never       1~3                  4~8              1~3
# 12670  never       never       1~3                  4~8              1~3
# 12682  never       never       1~3                  4~8              1~3
#
#        direction_same  direction_opp  Y
# 9                   0              1  0
# 13                  1              0  1
# 17                  0              1  0
# 24                  0              1  1
# 35                  1              0  1
# ...               ...            ... ..
# 12663               0              1  0
# 12664               0              1  0
# 12667               0              1  0
# 12670               0              1  0
# 12682               0              1  0
#
# [2007 rows x 22 columns]

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
data_bar = [data_coupon_bar[data_coupon_bar['Y']==1].shape[0],data_coupon_bar[data_coupon_bar['Y']!=1].shape[0]]
print(data_bar)
keys = ['Accepted', 'Not Accepted']
palette_color = sns.color_palette('bright')
plt.pie(data_bar, labels=keys, colors=palette_color, autopct='%.0f%%')
plt.title("Acceptance Rate of Bar Coupons")
plt.show()
# Out:
# [824, 1183]

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
data_coupon_bar['Bar'].unique()
# Out:
# array(['never', 'less1', '1~3', 'gt8', '4~8'], dtype=object)

# %%
data_coupon_bar['Bar_times'] = data_coupon_bar['Bar'].apply(lambda x: 'less than 3' if x in ['never', 'less1', '1~3'] else 'More than 3')
sns.countplot(data_coupon_bar, x="Bar_times", hue="Y").set(title="Acceptance between 3 or fewer times a month and rest")
# Out:
# /var/folders/6p/pk_vb21d3sz8bqltllmnd3700000gn/T/ipykernel_99104/669545902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_coupon_bar['Bar_times'] = data_coupon_bar['Bar'].apply(lambda x: 'less than 3' if x in ['never', 'less1', '1~3'] else 'More than 3')
# [Text(0.5, 1.0, 'Acceptance between 3 or fewer times a month and rest')]

# %%
data_coupon_bar['age'].unique()
# Out:
# array(['21', '46', '26', '31', '41', '50plus', '36', 'below21'],
#       dtype=object)

# %%
data_coupon_bar
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  has_children  \
# 9             1d  Female  21  Unmarried partner             1
# 13            1d  Female  21  Unmarried partner             1
# 17            1d  Female  21  Unmarried partner             1
# 24            1d    Male  21             Single             0
# 35            1d    Male  21             Single             0
# ...          ...     ...  ..                ...           ...
# 12663         1d    Male  26             Single             0
# 12664         2h    Male  26             Single             0
# 12667         1d    Male  26             Single             0
# 12670         2h    Male  26             Single             0
# 12682         1d    Male  26             Single             0
#
#                       education                  occupation           income  \
# 9      Some college - no degree                  Unemployed  $37500 - $49999
# 13     Some college - no degree                  Unemployed  $37500 - $49999
# 17     Some college - no degree                  Unemployed  $37500 - $49999
# 24             Bachelors degree  Architecture & Engineering  $62500 - $74999
# 35             Bachelors degree  Architecture & Engineering  $62500 - $74999
# ...                         ...                         ...              ...
# 12663          Bachelors degree             Sales & Related  $75000 - $87499
# 12664          Bachelors degree             Sales & Related  $75000 - $87499
# 12667          Bachelors degree             Sales & Related  $75000 - $87499
# 12670          Bachelors degree             Sales & Related  $75000 - $87499
# 12682          Bachelors degree             Sales & Related  $75000 - $87499
#
#          Bar CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 9      never       never       1~3                  4~8              1~3
# 13     never       never       1~3                  4~8              1~3
# 17     never       never       1~3                  4~8              1~3
# 24     never       less1       4~8                  4~8            less1
# 35     never       less1       4~8                  4~8            less1
# ...      ...         ...       ...                  ...              ...
# 12663  never       never       1~3                  4~8              1~3
# 12664  never       never       1~3                  4~8              1~3
# 12667  never       never       1~3                  4~8              1~3
# 12670  never       never       1~3                  4~8              1~3
# 12682  never       never       1~3                  4~8              1~3
#
#        direction_same  direction_opp  Y    Bar_times
# 9                   0              1  0  less than 3
# 13                  1              0  1  less than 3
# 17                  0              1  0  less than 3
# 24                  0              1  1  less than 3
# 35                  1              0  1  less than 3
# ...               ...            ... ..          ...
# 12663               0              1  0  less than 3
# 12664               0              1  0  less than 3
# 12667               0              1  0  less than 3
# 12670               0              1  0  less than 3
# 12682               0              1  0  less than 3
#
# [2007 rows x 23 columns]

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
def select_data(row):
    if (row['Bar'] in(['1~3', 'gt8', '4~8']) and (row['age'] in(['46', '26', '31', '41', '50plus', '36']))):
        return 'Yes'
    else:
        return 'No'
    
data_coupon_bar['25_and_more_than_once'] = data_coupon_bar.apply(lambda row : select_data(row), axis=1)

sns.countplot(data_coupon_bar, x="25_and_more_than_once", hue="Y").set(title="Acceptance rate between drivers go to a bar more than once a month and are over the age of 25 to the all others")
# Out:
# /var/folders/6p/pk_vb21d3sz8bqltllmnd3700000gn/T/ipykernel_99104/2296649516.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_coupon_bar['25_and_more_than_once'] = data_coupon_bar.apply(lambda row : select_data(row), axis=1)
# [Text(0.5, 1.0, 'Acceptance rate between drivers go to a bar more than once a month and are over the age of 25 to the all others')]

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
print(data_coupon_bar.passanger.unique())
print(data_coupon_bar.occupation.unique())
# Out:
# ['Kid(s)' 'Alone' 'Friend(s)' 'Partner']
# ['Unemployed' 'Architecture & Engineering' 'Student'
#  'Education&Training&Library' 'Healthcare Support'
#  'Healthcare Practitioners & Technical' 'Sales & Related' 'Management'
#  'Arts Design Entertainment Sports & Media' 'Computer & Mathematical'
#  'Life Physical Social Science' 'Personal Care & Service'
#  'Community & Social Services' 'Office & Administrative Support'
#  'Construction & Extraction' 'Legal' 'Retired'
#  'Installation Maintenance & Repair' 'Transportation & Material Moving'
#  'Business & Financial' 'Protective Service'
#  'Food Preparation & Serving Related' 'Production Occupations'
#  'Building & Grounds Cleaning & Maintenance' 'Farming Fishing & Forestry']

# %%
data_coupon_bar[['Bar','passanger','occupation','Y']]
# Out:
#          Bar  passanger                  occupation  Y
# 9      never     Kid(s)                  Unemployed  0
# 13     never      Alone                  Unemployed  1
# 17     never      Alone                  Unemployed  0
# 24     never  Friend(s)  Architecture & Engineering  1
# 35     never      Alone  Architecture & Engineering  1
# ...      ...        ...                         ... ..
# 12663  never  Friend(s)             Sales & Related  0
# 12664  never  Friend(s)             Sales & Related  0
# 12667  never      Alone             Sales & Related  0
# 12670  never    Partner             Sales & Related  0
# 12682  never      Alone             Sales & Related  0
#
# [2007 rows x 4 columns]

# %%
df5 = data_coupon_bar[['Bar','passanger','occupation','Y']]

def select_df5(row):
    if ((row['Bar'] in(['1~3', 'gt8', '4~8'])) and (row['passanger'] !='Kid(s)') and \
        (row['occupation'] not in(['farming', 'fishing','forestry']))):
        return 'Yes'
    else:
        return 'No'

df5['drivers']= df5.apply(lambda row : select_df5(row), axis=1 )
df5_total_data = df5.groupby('drivers').agg({'Y': 'sum','drivers':'size'})
df5_total_data.rename(columns={'drivers':'count'},inplace=True)
df5_total_data.reset_index()

print(df5_total_data)
sns.displot(data=df5, x='drivers',  hue = 'Y', multiple='stack').set(title = 'Drivers :> once a month, passengers not kids, occupations other than farming, fishing, or forestry.')
# Out:
#            Y  count
# drivers
# No       431   1456
# Yes      393    551
# /var/folders/6p/pk_vb21d3sz8bqltllmnd3700000gn/T/ipykernel_99104/1112418834.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['drivers']= df5.apply(lambda row : select_df5(row), axis=1 )
# /Users/krishnakuncham/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
print(data_coupon_bar.Bar.unique())
print(data_coupon_bar.passanger.unique())
print(data_coupon_bar.maritalStatus.unique())
print(data_coupon_bar.age.unique())
print(data_coupon_bar.RestaurantLessThan20.unique())
print(data_coupon_bar.income.unique())
# Out:
# ['never' 'less1' '1~3' 'gt8' '4~8']
# ['Kid(s)' 'Alone' 'Friend(s)' 'Partner']
# ['Unmarried partner' 'Single' 'Married partner' 'Divorced' 'Widowed']
# ['21' '46' '26' '31' '41' '50plus' '36' 'below21']
# ['4~8' '1~3' 'less1' 'gt8' 'never']
# ['$37500 - $49999' '$62500 - $74999' '$12500 - $24999' '$75000 - $87499'
#  '$50000 - $62499' '$25000 - $37499' '$100000 or More' '$87500 - $99999'
#  'Less than $12500']

# %%
df6 = data_coupon_bar[['Bar','passanger','maritalStatus','age','RestaurantLessThan20','income','Y']]

def select_df6(row):
    if (((row['Bar'] in(['1~3', 'gt8', '4~8'])) and (row['passanger'] !='Kid(s)') and (row['maritalStatus'] !='Widowed')) or \
        ((row['Bar'] in(['1~3', 'gt8', '4~8'])) and (row['age'] in ['21' , '26', 'below21']) ) or \
        ((row['RestaurantLessThan20'] in(['gt8', '4~8'])) and (row['income'] in ['$12500 - $24999','$37500 - $49999','$25000 - $37499','Less than $12500'])     )
       ):
        return 'Yes'
    else:
        return 'No'
    
df6['drivers']= df6.apply(lambda row : select_df6(row), axis=1 )
df6_total_data = df6.groupby('drivers').agg({'Y': 'sum','drivers':'size'})
df6_total_data.rename(columns={'drivers':'count'},inplace=True)
df6_total_data.reset_index()

print(df6_total_data)
sns.displot(data=df6, x='drivers',  hue = 'Y', multiple='stack').set(title = 'Drivers hotting bar more than onece, no kids, not widowed,under 30, cheap restaurant, income < 50K')
# Out:
# /var/folders/6p/pk_vb21d3sz8bqltllmnd3700000gn/T/ipykernel_99104/2528417113.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['drivers']= df6.apply(lambda row : select_df6(row), axis=1 )
#            Y  count
# drivers
# No       367   1231
# Yes      457    776
# /Users/krishnakuncham/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# Drivers who are more than 25 in age and frequent the bars more than once a month accept the coupons than the rest of tge drivers.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
data_other_coupon_1 = data[data['Y']==1]
print(data_other_coupon_1[data_other_coupon_1['coupon']=='Coffee House'].shape)
print(data_other_coupon_1.shape)
cdf = (data_other_coupon_1[data_other_coupon_1['coupon']=='Coffee House'].shape[0])/(data_other_coupon_1.shape[0])*100
cdf
# Out:
# (1812, 22)
# (6979, 22)
# 25.96360510101734

# %% [markdown]
# # Out of all the coupon acceptances "Coffe House" has 26
# % acceptance rate.

# %%
data_coffee = data_other_coupon_1[data_other_coupon_1['coupon']=='Coffee House']
cat_cols = data_coffee.columns[data_coffee.dtypes == 'object']
cat_dict = {}
for col in cat_cols:
    col_val_uni = data_coffee[col].unique()
    assign_vals = {value: index for index, value in enumerate(col_val_uni)}
    cat_dict[col] = assign_vals
data_coffee = data_coffee.replace(cat_dict)
data_coffee
# Out:
#        destination  passanger  weather  temperature  time  coupon  expiration  \
# 12               0          0        0           55     0       0           0
# 16               1          1        0           55     1       0           0
# 45               0          2        0           80     2       0           0
# 48               0          2        0           80     3       0           1
# 49               0          2        0           80     3       0           0
# ...            ...        ...      ...          ...   ...     ...         ...
# 12579            2          1        1           55     4       0           0
# 12601            2          1        1           55     4       0           0
# 12608            1          1        2           30     1       0           1
# 12624            2          1        1           55     4       0           0
# 12631            1          1        2           30     1       0           1
#
#        gender  age  maritalStatus  has_children  education  occupation  \
# 12          0    0              0             1          0           0
# 16          0    0              0             1          0           0
# 45          1    1              1             0          0           1
# 48          1    1              1             0          0           1
# 49          1    1              1             0          0           1
# ...       ...  ...            ...           ...        ...         ...
# 12579       1    0              1             0          0           1
# 12601       0    5              3             1          0           9
# 12608       0    5              3             1          0           9
# 12624       0    0              0             0          1           0
# 12631       0    0              0             0          1           0
#
#        income  Bar  CoffeeHouse  CarryAway  RestaurantLessThan20  \
# 12          0    0            0          0                     0
# 16          0    0            0          0                     0
# 45          1    0            1          0                     1
# 48          1    0            1          0                     1
# 49          1    0            1          0                     1
# ...       ...  ...          ...        ...                   ...
# 12579       1    0            0          0                     1
# 12601       1    0            3          0                     1
# 12608       1    0            3          0                     1
# 12624       0    0            1          0                     1
# 12631       0    0            1          0                     1
#
#        Restaurant20To50  direction_same  direction_opp  Y
# 12                    0               0              1  1
# 16                    0               0              1  1
# 45                    1               0              1  1
# 48                    1               0              1  1
# 49                    1               0              1  1
# ...                 ...             ...            ... ..
# 12579                 2               1              0  1
# 12601                 2               1              0  1
# 12608                 2               1              0  1
# 12624                 2               1              0  1
# 12631                 2               1              0  1
#
# [1812 rows x 22 columns]

# %%
data_coffee.corr()
# Out:
#                       destination  passanger   weather  temperature      time  \
# destination              1.000000  -0.339549  0.304311    -0.157945 -0.511817
# passanger               -0.339549   1.000000 -0.128780     0.253626  0.315349
# weather                  0.304311  -0.128780  1.000000    -0.727623 -0.015151
# temperature             -0.157945   0.253626 -0.727623     1.000000 -0.004891
# time                    -0.511817   0.315349 -0.015151    -0.004891  1.000000
# coupon                        NaN        NaN       NaN          NaN       NaN
# expiration               0.097081  -0.103197  0.187189    -0.143088 -0.042569
# gender                   0.031141   0.001635  0.016876    -0.029572 -0.019332
# age                      0.027443  -0.038097  0.053099    -0.002715 -0.014264
# maritalStatus           -0.002955  -0.121120  0.020839    -0.008881  0.005467
# has_children            -0.026547  -0.229987 -0.005121     0.006331  0.010474
# education               -0.011744  -0.034223 -0.018984     0.012909 -0.032768
# occupation              -0.024172   0.014105  0.018187     0.003452  0.044022
# income                  -0.011683  -0.011416 -0.008923     0.027946  0.021248
# Bar                      0.020125   0.045852 -0.051058     0.017241 -0.044350
# CoffeeHouse             -0.013598   0.017411  0.017570     0.004664  0.010060
# CarryAway               -0.038686  -0.010886  0.038449    -0.024875  0.025218
# RestaurantLessThan20    -0.001222  -0.010800  0.011996    -0.020042  0.017709
# Restaurant20To50         0.036279  -0.039899  0.077669    -0.063788 -0.012101
# direction_same           0.550208  -0.199289  0.288420    -0.078542 -0.258091
# direction_opp           -0.550208   0.199289 -0.288420     0.078542  0.258091
# Y                             NaN        NaN       NaN          NaN       NaN
#
#                       coupon  expiration    gender       age  maritalStatus  \
# destination              NaN    0.097081  0.031141  0.027443      -0.002955
# passanger                NaN   -0.103197  0.001635 -0.038097      -0.121120
# weather                  NaN    0.187189  0.016876  0.053099       0.020839
# temperature              NaN   -0.143088 -0.029572 -0.002715      -0.008881
# time                     NaN   -0.042569 -0.019332 -0.014264       0.005467
# coupon                   NaN         NaN       NaN       NaN            NaN
# expiration               NaN    1.000000  0.005095  0.049779       0.035774
# gender                   NaN    0.005095  1.000000  0.014718      -0.033018
# age                      NaN    0.049779  0.014718  1.000000       0.202707
# maritalStatus            NaN    0.035774 -0.033018  0.202707       1.000000
# has_children             NaN    0.039363 -0.155409  0.246346       0.484120
# education                NaN    0.048931 -0.060388  0.077590       0.113211
# occupation               NaN   -0.007689  0.066796  0.124715       0.085178
# income                   NaN    0.002629 -0.017007  0.055313       0.068098
# Bar                      NaN   -0.039413  0.144900 -0.189655      -0.118505
# CoffeeHouse              NaN   -0.018681 -0.014338  0.031992       0.048565
# CarryAway                NaN    0.058126 -0.003687  0.074800       0.005460
# RestaurantLessThan20     NaN   -0.006723  0.037414 -0.005276      -0.004966
# Restaurant20To50         NaN    0.032111  0.021507  0.066657       0.043178
# direction_same           NaN    0.181754  0.009294  0.022337       0.000606
# direction_opp            NaN   -0.181754 -0.009294 -0.022337      -0.000606
# Y                        NaN         NaN       NaN       NaN            NaN
#
#                       has_children  education  occupation    income       Bar  \
# destination              -0.026547  -0.011744   -0.024172 -0.011683  0.020125
# passanger                -0.229987  -0.034223    0.014105 -0.011416  0.045852
# weather                  -0.005121  -0.018984    0.018187 -0.008923 -0.051058
# temperature               0.006331   0.012909    0.003452  0.027946  0.017241
# time                      0.010474  -0.032768    0.044022  0.021248 -0.044350
# coupon                         NaN        NaN         NaN       NaN       NaN
# expiration                0.039363   0.048931   -0.007689  0.002629 -0.039413
# gender                   -0.155409  -0.060388    0.066796 -0.017007  0.144900
# age                       0.246346   0.077590    0.124715  0.055313 -0.189655
# maritalStatus             0.484120   0.113211    0.085178  0.068098 -0.118505
# has_children              1.000000   0.100108    0.120567 -0.030733 -0.205064
# education                 0.100108   1.000000   -0.013970 -0.007323  0.038075
# occupation                0.120567  -0.013970    1.000000 -0.101082  0.068945
# income                   -0.030733  -0.007323   -0.101082  1.000000  0.053586
# Bar                      -0.205064   0.038075    0.068945  0.053586  1.000000
# CoffeeHouse               0.020777  -0.051489   -0.012996  0.065743  0.039282
# CarryAway                 0.036280   0.021915    0.037484 -0.048409 -0.035315
# RestaurantLessThan20     -0.071437  -0.060298    0.029202 -0.000193 -0.057762
# Restaurant20To50          0.005167   0.030198    0.024026 -0.019545  0.082683
# direction_same           -0.032859   0.010594   -0.015947  0.020033 -0.007008
# direction_opp             0.032859  -0.010594    0.015947 -0.020033  0.007008
# Y                              NaN        NaN         NaN       NaN       NaN
#
#                       CoffeeHouse  CarryAway  RestaurantLessThan20  \
# destination             -0.013598  -0.038686             -0.001222
# passanger                0.017411  -0.010886             -0.010800
# weather                  0.017570   0.038449              0.011996
# temperature              0.004664  -0.024875             -0.020042
# time                     0.010060   0.025218              0.017709
# coupon                        NaN        NaN                   NaN
# expiration              -0.018681   0.058126             -0.006723
# gender                  -0.014338  -0.003687              0.037414
# age                      0.031992   0.074800             -0.005276
# maritalStatus            0.048565   0.005460             -0.004966
# has_children             0.020777   0.036280             -0.071437
# education               -0.051489   0.021915             -0.060298
# occupation              -0.012996   0.037484              0.029202
# income                   0.065743  -0.048409             -0.000193
# Bar                      0.039282  -0.035315             -0.057762
# CoffeeHouse              1.000000   0.006383              0.087259
# CarryAway                0.006383   1.000000              0.052338
# RestaurantLessThan20     0.087259   0.052338              1.000000
# Restaurant20To50         0.090067   0.052158              0.015263
# direction_same          -0.023380   0.021064              0.011253
# direction_opp            0.023380  -0.021064             -0.011253
# Y                             NaN        NaN                   NaN
#
#                       Restaurant20To50  direction_same  direction_opp   Y
# destination                   0.036279        0.550208      -0.550208 NaN
# passanger                    -0.039899       -0.199289       0.199289 NaN
# weather                       0.077669        0.288420      -0.288420 NaN
# temperature                  -0.063788       -0.078542       0.078542 NaN
# time                         -0.012101       -0.258091       0.258091 NaN
# coupon                             NaN             NaN            NaN NaN
# expiration                    0.032111        0.181754      -0.181754 NaN
# gender                        0.021507        0.009294      -0.009294 NaN
# age                           0.066657        0.022337      -0.022337 NaN
# maritalStatus                 0.043178        0.000606      -0.000606 NaN
# has_children                  0.005167       -0.032859       0.032859 NaN
# education                     0.030198        0.010594      -0.010594 NaN
# occupation                    0.024026       -0.015947       0.015947 NaN
# income                       -0.019545        0.020033      -0.020033 NaN
# Bar                           0.082683       -0.007008       0.007008 NaN
# CoffeeHouse                   0.090067       -0.023380       0.023380 NaN
# CarryAway                     0.052158        0.021064      -0.021064 NaN
# RestaurantLessThan20          0.015263        0.011253      -0.011253 NaN
# Restaurant20To50              1.000000        0.025512      -0.025512 NaN
# direction_same                0.025512        1.000000      -1.000000 NaN
# direction_opp                -0.025512       -1.000000       1.000000 NaN
# Y                                  NaN             NaN            NaN NaN

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(data_coffee.corr(), annot=True, cmap='coolwarm', fmt='.1f'  )
plt.title('Correlation Heatmap')
plt.show()
